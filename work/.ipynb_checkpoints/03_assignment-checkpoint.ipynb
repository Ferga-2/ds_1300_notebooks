# %% [markdown]
# # Linear Regression and Temperature

# %% [markdown]
# In this notebook, we'll look at using linear regression to study changes in temperature.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# ## Getting our data

# %% [markdown]
# We'll be getting data from [North America Land Data Assimilation System (NLDAS)](https://wonder.cdc.gov/NASA-NLDAS.html), which provides the daily average temperature from 1979-2011 for the United States.

# %% [markdown]
# For the next step, you will need to choose some settings in the data request form. These are:
#
# - GroupBy: Month Day, Year
# - Your State
# - Export Results (check box)
# - Show Zero Values (check box)

# %% [markdown]
# >1) Download the data for your home state (or state of your choosing) and upload it to M2 in your work directory.

# %% [markdown]
# # Loading our data

# %%
df = pd.read_csv('Temp.txt',delimiter='\t',skipfooter=14,engine='python')

# %%
df.head()
# Out:
#    Notes Month Day, Year Month Day, Year Code  \
# 0    NaN    Jan 01, 1979           1979/01/01
# 1    NaN    Jan 02, 1979           1979/01/02
# 2    NaN    Jan 03, 1979           1979/01/03
# 3    NaN    Jan 04, 1979           1979/01/04
# 4    NaN    Jan 05, 1979           1979/01/05
#
#    Avg Daily Max Air Temperature (F)  Avg Daily Min Air Temperature (F)  \
# 0                              29.03                              15.16
# 1                              31.35                              11.76
# 2                              41.66                              19.72
# 3                              47.30                              30.59
# 4                              46.89                              31.94
#
#   Avg Daily Max Heat Index (F)
# 0                      Missing
# 1                      Missing
# 2                      Missing
# 3                      Missing
# 4                      Missing

# %% [markdown]
# ### Clean the data

# %% [markdown]
# >2) Drop any rows that have the value "Total" in the Notes column, then drop the Notes column

# %%
df = df[df.Notes != "Total"]

# %%
df = df.drop(columns=['Notes'])
df.head()
# Out:
#   Month Day, Year Month Day, Year Code  Avg Daily Max Air Temperature (F)  \
# 0    Jan 01, 1979           1979/01/01                              29.03
# 1    Jan 02, 1979           1979/01/02                              31.35
# 2    Jan 03, 1979           1979/01/03                              41.66
# 3    Jan 04, 1979           1979/01/04                              47.30
# 4    Jan 05, 1979           1979/01/05                              46.89
#
#    Avg Daily Min Air Temperature (F) Avg Daily Max Heat Index (F)
# 0                              15.16                      Missing
# 1                              11.76                      Missing
# 2                              19.72                      Missing
# 3                              30.59                      Missing
# 4                              31.94                      Missing

# %% [markdown]
# >3) Make a column called Date that is in the pandas datetime format

# %%
df['Date']=pd.to_datetime(df['Month Day, Year'])
df.head()
# Out:
#   Month Day, Year Month Day, Year Code  Avg Daily Max Air Temperature (F)  \
# 0    Jan 01, 1979           1979/01/01                              29.03
# 1    Jan 02, 1979           1979/01/02                              31.35
# 2    Jan 03, 1979           1979/01/03                              41.66
# 3    Jan 04, 1979           1979/01/04                              47.30
# 4    Jan 05, 1979           1979/01/05                              46.89
#
#    Avg Daily Min Air Temperature (F) Avg Daily Max Heat Index (F)       Date
# 0                              15.16                      Missing 1979-01-01
# 1                              11.76                      Missing 1979-01-02
# 2                              19.72                      Missing 1979-01-03
# 3                              30.59                      Missing 1979-01-04
# 4                              31.94                      Missing 1979-01-05

# %% [markdown]
# >4) Make columns for 'Year', 'Month', and 'Day' by splitting the column 'Month Day, Year'

# %%
df['Year'] = pd.DatetimeIndex(df['Date']).year
df['Month'] = pd.DatetimeIndex(df['Date']).month
df['Day'] = pd.DatetimeIndex(df['Date']).day
df.head()
# Out:
#   Month Day, Year Month Day, Year Code  Avg Daily Max Air Temperature (F)  \
# 0    Jan 01, 1979           1979/01/01                              29.03
# 1    Jan 02, 1979           1979/01/02                              31.35
# 2    Jan 03, 1979           1979/01/03                              41.66
# 3    Jan 04, 1979           1979/01/04                              47.30
# 4    Jan 05, 1979           1979/01/05                              46.89
#
#    Avg Daily Min Air Temperature (F) Avg Daily Max Heat Index (F)       Date  \
# 0                              15.16                      Missing 1979-01-01
# 1                              11.76                      Missing 1979-01-02
# 2                              19.72                      Missing 1979-01-03
# 3                              30.59                      Missing 1979-01-04
# 4                              31.94                      Missing 1979-01-05
#
#    Year  Month  Day
# 0  1979      1    1
# ...

# %%
cols = ["Date","Year","Month","Day","Avg Daily Max Air Temperature (F)","Avg Daily Min Air Temperature (F)","Avg Daily Max Heat Index (F)"]
df = pd.DataFrame(df, columns = cols)
df.tail()
# Out:
#             Date  Year  Month  Day  Avg Daily Max Air Temperature (F)  \
# 12034 2011-12-13  2011     12   13                              69.30
# 12035 2011-12-14  2011     12   14                              71.49
# 12036 2011-12-15  2011     12   15                              63.47
# 12037 2011-12-16  2011     12   16                              54.61
# 12038 2011-12-17  2011     12   17                              56.60
#
#        Avg Daily Min Air Temperature (F) Avg Daily Max Heat Index (F)
# 12034                              49.84                      Missing
# 12035                              55.14                        84.91
# 12036                              46.60                        83.63
# 12037                              41.57                      Missing
# 12038                              41.10                      Missing

# %%
df['DateInt'] = df['Date'].astype(int)/10e10 # This will be used later

# %% [markdown]
# ## Generating a scatter plot

# %% [markdown]
# > 4) Use df.plot.scatter to plot 'Date' vs 'Avg Daily Max Air Temperature (F)'. You might want to add figsize=(50,5) as an argument to make it more clear what is happening.

# %%
 columns = ["Date","Avg Daily Max Air Temperature (F)"]
Max_Temp = df.plot.scatter(x='Date',y='Avg Daily Max Air Temperature (F)',c='Black',figsize =(50,5))

# %% [markdown]
# >5) Describe your plot.

# %%
print("This is a scatter plot that shows the average daily max temperature in Texas for every day from 1979-2011")
# Out:
# This is a scatter plot that shows the average daily max temperature in Texas for every day from 1979-2011

# %% [markdown]
# ### Adding colors for our graph

# %%
# No need to edit this unless you want to try different colors or a pattern other than colors by month

cmap = matplotlib.cm.get_cmap("nipy_spectral", len(df['Month'].unique())) # Builds a discrete color mapping using a built in matplotlib color map

c = []
for i in range(cmap.N): # Converts our discrete map into Hex Values
    rgba = cmap(i)
    c.append(matplotlib.colors.rgb2hex(rgba))

df['color']=[c[int(i-1)] for i in df['Month'].astype(int)] # Adds a column to our dataframe with the color we want for each row

# %% [markdown]
# >6) Make the same plot as 4) but add color by adding the argument c=df\['color'\] to our plotting command.

# %%
 columns = ["Date","Avg Daily Max Air Temperature (F)"]
Max_Temp = df.plot.scatter(x='Date',y='Avg Daily Max Air Temperature (F)',c=df["color"],figsize =(50,5))

# %% [markdown]
# ## Pick a subset of the data

# %% [markdown]
# >7) Select a 6 month period from the data. # Hint use logic and pd.datetime(YYYY, MM, DD)

# %%
subset = df[(df['Date'] >= '2001-01-01') & (df['Date'] <= '2001-06-30')]
subset.head()
# Out:
#            Date  Year  Month  Day  Avg Daily Max Air Temperature (F)  \
# 8036 2001-01-01  2001      1    1                              44.38
# 8037 2001-01-02  2001      1    2                              39.15
# 8038 2001-01-03  2001      1    3                              46.16
# 8039 2001-01-04  2001      1    4                              55.30
# 8040 2001-01-05  2001      1    5                              59.09
#
#       Avg Daily Min Air Temperature (F) Avg Daily Max Heat Index (F)  \
# 8036                              28.96                      Missing
# 8037                              28.20                      Missing
# 8038                              27.85                      Missing
# 8039                              31.91                      Missing
# 8040                              37.33                      Missing
#
#         DateInt    color
# 8036  9783072.0  #000000
# 8037  9783936.0  #000000
# 8038  9784800.0  #000000
# 8039  9785664.0  #000000
# ...

# %% [markdown]
# >8) Plot the subset using the the same code you used in 6). You can change the figsize if needed.

# %%
 columns = ["Date","Avg Daily Max Air Temperature (F)"]
subset_plot = subset.plot.scatter(x='Date',y='Avg Daily Max Air Temperature (F)',c=subset["color"])

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# We are going to use a very [simple linear regression model](https://en.wikipedia.org/wiki/Simple_linear_regression). You may implement a more complex model if you wish.
#
# The method described here is called the least squares method and is defined as:
#
# $m = \frac{\sum_{i=1}^{n}(x_i-\bar{x})(y_i-\bar{y}))}{\sum_{i=1}^{n}(x_i-\bar{x})^2}$
#
# $b = \bar{y} - m\bar{x}$
#
# Where $\bar{x}$ and $\bar{y}$ are the average value of $x$ and $y$ respectively.

# %% [markdown]
# First we need to define our X and Y values.

# %%
X=subset['DateInt'].values
Y=subset['Avg Daily Max Air Temperature (F)'].values

# %%
def lin_reg(x,y):
    # Calculate the average x and y
    x_avg = np.mean(x)
    y_avg = np.mean(y)

    num = 0
    den = 0
    for i in range(len(x)): # This represents our sums
        num = num + (x[i] - x_avg)*(y[i] - y_avg) # Our numerator
        den = den + (x[i] - x_avg)**2 # Our denominator
    # Calculate slope
    m = num / den
    # Calculate intercept
    b = y_avg - m*x_avg

    print (m, b)
    
    # Calculate our predicted y values
    y_pred = m*x + b
    
    return y_pred

# %%
Y_pred = lin_reg(X,Y)
# Out:
# 0.000302336186083884 -2907.2672224718185

# %%
subset.plot.scatter(x='Date', y='Avg Daily Max Air Temperature (F)',c=subset['color'])
plt.plot([min(subset['Date'].values), max(subset['Date'].values)], [min(Y_pred), max(Y_pred)], color='red') # best fit line
plt.show()

# %% [markdown]
# >9) What are the slope and intercept of your best fit line?

# %%
print("slope = 0.000302336186083884 intercept = 2907.2672224718185")
# Out:
# slope = 0.000302336186083884 intercept = 2907.2672224718185

# %% [markdown]
# >10) What are the minimum and maximum Y values of your best fit line? Is your slope positive or negative?

# %%
min(Y_pred)
# Out:
# 50.50945419221671

# %%
max(Y_pred)
# Out:
# 97.52877785198234

# %% [markdown]
# ## Putting it all together

# %% [markdown]
# >11) Generate a best fit line for the full data set and plot the line over top of the data.

# %%
X=df['DateInt'].values
Y=df['Avg Daily Max Air Temperature (F)'].values

# %%
Y_pred = lin_reg(X,Y)
# Out:
# 3.218820384689774e-07 75.57782818702483

# %%
df.plot.scatter(x='Date', y='Avg Daily Max Air Temperature (F)',c=df['color'],figsize=(50,5))
plt.plot([min(df['Date'].values), max(df['Date'].values)], [min(Y_pred), max(Y_pred)], color='red') # best fit line
plt.show()

# %% [markdown]
# >12) Is the slope positive or negative? What do you think that means?

# %%
print("The Slope is positive meaning the average max temperature in texas is steadily increasing over time")
# Out:
# The Slope is positive meaning the average max temperature in texas is steadily increasing over time
